# %% [markdown]
# <a href="https://colab.research.google.com/github/sreekar-1726/python-new/blob/module4/26_05_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(ypoints, marker = '*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(ypoints, 'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'b')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(x, y)

plt.xlabel("subjects")
plt.ylabel("grades")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])


plt.plot(x, y)

plt.title("semister graph")
plt.xlabel("subject")
plt.ylabel("grades")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(ypoints, color = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(ypoints, color = 'g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(ypoints, color = 'r')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

font1 = {'family':'serif','color':'green','size':20}
font2 = {'family':'serif','color':'blue','size':15}

plt.title("semister graph", fontdict = font1)
plt.xlabel("subjects", fontdict = font2)
plt.ylabel("grades", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.title("semister graph")
plt.xlabel("subject")
plt.ylabel("grades")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.title("semister graph")
plt.xlabel("subject")
plt.ylabel("grades")


plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y = np.array([9,8.5,7,7.5,7.8,8,9,9.4,7,])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y = np.array([9,8.5,7,7.5,7.8,8,9,9.4,7,])


plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(ypoints, linewidth = '10.5')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
y2 = np.array([6, 2, 7, 10, 6.5, 8, 9, 9.5, 8.5, 9.5])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot1
x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
plt.scatter(x, y)

#plot2
x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y = np.array([9,8.5,7,7.5,7.8,8,9,9.4,7,])
plt.scatter(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
plt.scatter(x, y, color = 'green')

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y = np.array([9,8.5,7,7.5,7.8,8,9,9.4,7,])
plt.scatter(x, y, color = 'blue')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(9,7,8)

plt.hist(x)
plt.show()

# %%
import numpy as np

x = np.random.normal(120,34,150)

print(x)
# Out:
# [123.88482857 191.97012912  81.92353758 115.12287918 177.56633603
#  180.93086911  62.33882014 143.6569922  170.21023128 128.15136562
#   95.49958249 108.92137809 111.2935977   92.94068611 138.89219093
#  126.70761708 134.3798759  118.48420251 155.80101252 124.86391165
#  102.46487227 124.50439655 117.85638906 153.87761978 105.68523747
#  102.12276786 139.01935094  64.42233186  96.38965315 171.92996349
#  147.83345108 137.85588633 173.13983035 122.55049371 129.32452973
#  105.11234133 147.6213965  145.38250319 113.21372649 136.56028138
#   63.50054521 111.02059556  95.61914043 125.89730273 104.7527249
#  138.18801805  96.85687004  71.19912118 120.18670535 130.18215232
#  102.68873464 124.4176431   65.7704438  133.54100635 118.33917617
#  105.4886606  117.67155852 188.01049874 138.73245104  57.99143498
#  152.98120319 119.74629008 137.12398692 115.03773491 125.08989814
#  131.89607322  38.84259388 115.49319611 110.34096    201.25069029
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.bar(x, y, color = "green")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.barh(x, y, height = 0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([13, 18, 19, 20])

plt.bar(x, y, width = 0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([5, 10, 15, 18])

plt.bar(x, y, color = "hotpink")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
mylabels = ["clad","it","comp","math-1","math-2","phy","mec","vdc","eng"]

plt.pie(y, labels = mylabels)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
mylabels = ["clad","it","comp","math-1","math-2","phy","mec","vdc","eng"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
mylabels = ["clad","it","comp","math-1","math-2","phy","mec","vdc","eng"]
myexplode = [0.2, 0.1, 0, 0,0.1,0,0,0,0.2]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
mylabels = ["clad","it","comp","math-1","math-2","phy","mec","vdc","eng"]
myexplode = [0.2, 0.1, 0.3, 0,0.4,0.8,0.7,0.6,0.5]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
mylabels = ["clad","it","comp","math-1","math-2","phy","mec","vdc","eng"]
mycolors = ["black", "pink", "brown", "green","red","blue","yellow","orange","silver"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
mylabels = ["clad","it","comp","math-1","math-2","phy","mec","vdc","eng"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
mylabels = ["clad","it","comp","math-1","math-2","phy","mec","vdc","eng"]

plt.pie(y, labels = mylabels)
plt.legend(title = "semister grades:")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
mylabels = ["clad","it","comp","math-1","math-2","phy","mec","vdc","eng"]
myexplode = [0.2, 0.1, 0.3, 0,0.4,0.8,0.7,0.6,0.5]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.legend(title = "semister grades:")
plt.show()
